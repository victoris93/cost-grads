# %%
import numpy as np
import pandas as pd
import os
import pickle
import seaborn as sns
from pycaret.regression import *

# %%
data = pd.read_csv("distances_Tpeak_temporal_ind_24102023_wide.csv")
data = data[(data["FlashType"] == 1) | (data["FlashType"] == 2)]
data = data.drop(["participant_id","correct", "rt","correct_abs", "rt_abs", "rt_Cod","rt_rel", "bl_correct","bl_rt", "CFF"], axis=1, index=None)
num_features = data.columns[4:].to_list()
# ord_features = [data_flash1.columns[0]]
cat_features = ['FlashType', 'NrBeeps', 'sex']

# %%
num_features
# Out:
# ['age',
#  'Dist to A1, LH',
#  'Dist to A1, RH',
#  'Dist to V1, LH',
#  'Dist to V1, RH',
#  'dist_ratio_L',
#  'dist_ratio_R']

# %%
cat_features
# Out:
# ['FlashType', 'NrBeeps', 'sex']

# %%
setup(data, target = 'correct_rel', session_id=123, normalize = True, ordinal_features = None, numeric_features = num_features, categorical_features = cat_features)
# Out:
# <style type="text/css">
# #T_e8911_row10_col1, #T_e8911_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e8911">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8911_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e8911_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8911_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8911_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e8911_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e8911_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8911_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e8911_row1_col1" class="data row1 col1" >correct_rel</td>
#     </tr>
#     <tr>
#       <th id="T_e8911_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# compare baseline models
best = compare_models()
# Out:
# <style type="text/css">
# #T_0d4f4 th {
#   text-align: left;
# }
# ...
